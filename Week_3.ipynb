# %% [markdown]
# <a href="https://colab.research.google.com/github/jmarcano101/data110/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

# %%
# @title Default title text
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(0, 1, 1000)
plt.hist(data,bins=30)
plt.title('Data Visualization Graph')
plt.xlabel('value')
plt.ylabel('frequency')
plt.hist(data, color='DEEPPINK')
plt.show()

# %%
plt.hist(data, bins=40)
plt.show()
plt.hist(data, bins=50)
plt.hist(data, color='PURPLE')
plt.show()

# %%
import pandas as pd
file_path = 'data.csv'
