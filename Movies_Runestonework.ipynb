# %% [markdown]
# <a href="https://colab.research.google.com/github/jmarcano101/data110/blob/main/Movies_Runestonework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/movies_metadata.csv").dropna(axis=1, how='all')
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage       id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862.0  tt0114709                en
# 1                                   NaN   8844.0  tt0113497                en
# ...

# %%
df.shape
# Out:
# (45453, 23)

# %%
df.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
budget_df=pd.read_csv("/content/movies_metadata.csv")

# %%
filtered_df = budget_df[budget_df["budget"] > 1000000]

# %%
print(filtered_df)
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 3                                                    NaN  16000000
# 5                                                    NaN  60000000
# 6                                                    NaN  58000000
# ...                                                  ...       ...
# 45385                                                NaN   1254040
# 45389                                                NaN   2000000
# 45395                                                NaN   2000000
# 45399                                                NaN   2000000
# 45409                                                NaN   5000000
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %%
import pandas as pd
budget_df = pd.read_csv("/content/movies_metadata.csv")
filtered_df = budget_df[budget_df["budget"] > 1000000]
movie_count = len(filtered_df)
print(f"Number of movies with a budget over 1 million dollars: {movie_count}")
# Out:
# Number of movies with a budget over 1 million dollars: 7208

# %%
import collections

# %%
budget_lookup = collections.defaultdict(object)

# %%
budget_lookup = pd.DataFrame.from_dict(budget_lookup, orient='index')

# %%
"/content/movies_metadata.csv" in budget_lookup.index
# Out:
# False

# %%
import pandas as pd
movies = pd.read_csv("/content/movies_metadata.csv")
filtered_movies = movies[
    (movies["budget"] > 1000000) & (movies["title"].str.startswith(("A", "B")))
]
movie_count = len(filtered_movies)
print(f"Number of movies: {movie_count}")
# Out:
# Number of movies: 933

# %%
budget_lookup.index
# Out:
# RangeIndex(start=0, stop=45453, step=1)

# %%
budget_lookup.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage       id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862.0  tt0114709                en
# 1                                   NaN   8844.0  tt0113497                en
# ...

# %%
budget_lookup[budget_lookup.index == "/content/movies_metadata.csv"].sort_index()["budget"]
# Out:
# Series([], Name: budget, dtype: int64)

# %%
first_element = sorted_df[[0]]

# %%
import numpy as np
budget_lookup_as_and_bs = []
budget_lookup_as_and_bs = np.array(budget_lookup_as_and_bs)
print("How many movies with a budget of over a million dollars and whose title starts with an “A bag of Hammers” or a “Byzantium")
# Out:
# How many movies with a budget of over a million dollars and whose title starts with an “A bag of Hammers” or a “Byzantium

# %%
sorted_df = filtered_df.sort_index()

# %%
budget_lookup = pd.read_csv("/content/movies_metadata.csv")
movie_count = budget_lookup[budget_lookup['title'] == 'Dead Presidents']['budget'].values[0]
print("budget of dead presidents movie", movie_count)
# Out:
# budget of dead presidents movie 10000000
