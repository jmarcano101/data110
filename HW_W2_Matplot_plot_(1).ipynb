# %% [markdown]
# <a href="https://colab.research.google.com/github/jmarcano101/data110/blob/main/HW_W2_Matplot_plot_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("https://wilkelab.org/SDS375/datasets/tempnormals.csv")

# %%
df.head()
# Out:
#        location   station_id  temperature month_name  month  day        date  \
# 0  Death Valley  USC00042319         51.0        Jan      1    1  0000-01-01
# 1  Death Valley  USC00042319         51.2        Jan      1    2  0000-01-02
# 2  Death Valley  USC00042319         51.3        Jan      1    3  0000-01-03
# 3  Death Valley  USC00042319         51.4        Jan      1    4  0000-01-04
# 4  Death Valley  USC00042319         51.6        Jan      1    5  0000-01-05
#
#    day_of_year
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
# @title Temperature Distribution by Location

df.hist(column='temperature', by='location')
# Out:
# array([[<Axes: title={'center': 'Chicago'}>,
#         <Axes: title={'center': 'Death Valley'}>],
#        [<Axes: title={'center': 'Houston'}>,
#         <Axes: title={'center': 'San Diego'}>]], dtype=object)

# %%
dv = df[df['location'] == 'Death Valley']
dh=df[df['location']=='Houston']
dc=df[df['location']=='Chicago']
ds=df[df['location']=='San Diego']

# %%
dv.head(3)
# Out:
#        location   station_id  temperature month_name  month  day        date  \
# 0  Death Valley  USC00042319         51.0        Jan      1    1  0000-01-01
# 1  Death Valley  USC00042319         51.2        Jan      1    2  0000-01-02
# 2  Death Valley  USC00042319         51.3        Jan      1    3  0000-01-03
#
#    day_of_year
# 0            1
# 1            2
# 2            3

# %%
# @title month vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['month']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'month'}, axis=1)
              .sort_values('month', ascending=True))
  xs = counted['month']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = dv.sort_values('month', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('month')
_ = plt.ylabel('count()')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dv['day_of_year'], dv['temperature'])
plt.show()

# %%
plt.plot(dv['day_of_year'], dv['temperature'])
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title("Trend of Temperature in Death Valley")
plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.plot(dv['day_of_year'], dv['temperature'])
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title("Trend of Temperature in Death Valley")
plt.grid(True)
plt.show()

# %%
descriptive_data_dv = dv['temperature'].describe()
Average_dv = descriptive_data_dv['mean']
print(Average_dv)
# Out:
# 77.15382513661201

# %%
plt.style.use('ggplot')

plt.axhline(y=Average_dv, color='darkblue', linestyle='--', label='Average')
plt.plot(dv['day_of_year'], dv['temperature'], color='deeppink',label='Death Valley Temperature')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title("Trend of Temperature in Death Valley")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.style.use('ggplot')

plt.axhline(y=Average_dv, linestyle='--', color='black',label='Average')
plt.plot(dv['day_of_year'], dv['temperature'], label='Death Valley Temperature')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Trend Temperature in Death Valley',color='orange')
plt.grid(True)
plt.legend(facecolor='gray', framealpha=.8)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.style.use('ggplot')
plt.plot(dv['day_of_year'], dv['temperature'], label='Death Valley ')
plt.plot(dh['day_of_year'], dh['temperature'], label='Huston ')
plt.plot(dc['day_of_year'], dc['temperature'], label='Chicago')
plt.plot(ds['day_of_year'], ds['temperature'], label='San Diago ')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Trend Temperature in Death Valley',color='orange')
plt.grid(True)
plt.legend(facecolor='darkgray', framealpha=.8)
plt.savefig('Trend_Temp.png')
plt.show()
